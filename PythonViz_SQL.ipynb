# %% [markdown]
# # Data Preparation and Visualization

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

cnxn_string = ("postgresql+psycopg2://{username}:{pswd}"
              "@{host}:{port}/{database}")
print(cnxn_string)

engine = create_engine(cnxn_string.format(
    username="postgres",
    pswd="behappy",
    host="postgres",
    port=5432,
    database="sqlda"))

engine.execute("SELECT * FROM customers LIMIT 2;").fetchall()
# Out:
# postgresql+psycopg2://{username}:{pswd}@{host}:{port}/{database}
# [(1, None, 'Arlena', 'Riveles', None, 'ariveles0@stumbleupon.com', 'F', '98.36.172.246', None, None, None, None, None, None, None, datetime.datetime(2017, 4, 23, 0, 0)),
#  (2, 'Dr', 'Ode', 'Stovin', None, 'ostovin1@npr.org', 'M', '16.97.59.186', '314-534-4361', '2573 Fordem Parkway', 'Saint Louis', 'MO', '63116', 38.5814, -90.2625, datetime.datetime(2014, 10, 2, 0, 0))]

# %% [markdown]
# ## Scenario
#
# You are a team of extremely successful data scientists at a top motor dealership company. You need to create summary tables and visualizations that your boss will present at the next company shareholder meeting.  She has sent you the following e-mail describing what she needs.
#
# ***
# From: importantboss@topmotordealershipcompany.com
#
# To: datascienceteam@topmotordealershipcompany.com
#
# Subject: Data request for shareholder meeting
#
# We are planning to expand our services in states with the highest sales amounts.  For our next shareholder meeting, we need to provide more information about sales performance at the state level and possible reasons why sales are lower in some states.  Please send me information to address the following items for our next shareholder meeting along with your thoughts.
#
# 1. Sales performance at the state level (top 5 and bottom 5 states)
# 2. For the best performing states, which dealerships are performing well and how are they trending?
# 3. Is sales performance by state associated with the types of products sold (scooter vs. automobile)?
#
# Thank you!
#
# -Important Boss
#
# ***

# %% [markdown]
# Your team promptly comes up with the following plan.

# %% [markdown]
# ## Part 1: Visualizing the top and bottom performing states
#
# 1. Write a SELECT query that returns the total sales amount for each state from January 1, 2017 to now.  The table should have two columns, `state` and `total_sales_amount`, with one row for each state ordered by `total_sales_amount` in *descending* order. Make sure that `total_sales_amount` is rounded appropriately.
#
#
# 2. Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `sales_by_state`.
#
#
# 3. Display the rows in `sales_by_state` corresponding to the 5 states with the **largest** total sales amount in *descending* order.
#
#
# 4. Display the rows in `sales_by_state` corresponding to the 5 states with the **smallest** total sales amount in *ascending* order.
#
#
# 5. Visualize sales performance by state for the top and bottom performing states discovered in 1.3 and 1.4.  You can use more than one visualization.  These should be **presentation ready** (e.g. appropriate and complete titles and axis labels, remove unnecessary/distracting features, display date range for total sales, no overlapping axis labels, etc.).
#
# Include the code needed for each component of part 1 in the appropriate code block below.

# %%
#1.1 select query
query_1 = """
SELECT c.state, cast(SUM(s.sales_amount)as DECIMAL(20,2)) as total_sales_amount
from customers as c                                                          
INNER JOIN sales as s
ON c.customer_id = s.customer_id
Where s.sales_transaction_date>='2017-01-01' AND c.state IS NOT NULL
GROUP BY c.state
ORDER BY total_sales_amount desc;
"""

# %%
#1.2 create dataframe
sales_by_state = pd.read_sql_query(query_1,engine)
sales_by_state
# Out:
#    state  total_sales_amount
# 0     CA         15857815.99
# 1     TX         15425788.00
# 2     FL         10410607.25
# 3     NY          9523439.42
# 4     PA          5031834.85
# 5     DC          4747799.88
# 6     VA          4407463.98
# 7     OH          4198514.12
# 8     GA          4113195.33
# 9     MO          4002390.99
# 10    IL          3585130.76
# 11    NC          3575996.01
# 12    MN          3455946.36
# 13    IN          3294076.71
# 14    AL          3197966.52
# 15    WA          3072641.42
# 16    MI          3052826.66
# 17    TN          3011376.64
# 18    CO          2694911.29
# 19    LA          2558471.73
# 20    AZ          2266906.98
# 21    KY          2148697.84
# 22    MA          2133992.85
# 23    WV          2133073.28
# 24    OK          2095892.40
# 25    KS          2081442.62
# 26    WI          2063418.28
# 27    CT          1931432.95
# 28    NV          1875462.60
# 29    MD          1711213.00
# 30    SC          1461923.25
# 31    UT          1234198.39
# 32    AR           997384.16
# 33    OR           961368.60
# 34    ID           868799.12
# 35    MS           835088.79
# 36    NE           833143.33
# 37    IA           753738.45
# 38    AK           670069.33
# 39    NJ           646548.40
# 40    HI           641439.27
# 41    DE           578364.60
# 42    NM           560044.12
# 43    ND           415769.71
# 44    NH           371714.72
# 45    MT           163149.51
# 46    ME            36364.92
# 47    VT            30014.96
# 48    SD            24179.58
# 49    RI             6099.90
# 50    WY             3249.94

# %%
#1.3 display top 5 performing states
top_performing_states=(sales_by_state.sort_values(by='total_sales_amount', ascending=False, ignore_index=True).head())
top_performing_states
# Out:
#   state  total_sales_amount
# 0    CA         15857815.99
# 1    TX         15425788.00
# 2    FL         10410607.25
# 3    NY          9523439.42
# 4    PA          5031834.85

# %%
#1.4 display bottom 5 performing states
bottom_performing_states=(sales_by_state.sort_values(by='total_sales_amount', ascending=True, ignore_index=True).head())
bottom_performing_states
# Out:
#   state  total_sales_amount
# 0    WY             3249.94
# 1    RI             6099.90
# 2    SD            24179.58
# 3    VT            30014.96
# 4    ME            36364.92

# %%
#1.5 visualize top  performing states


#Setting the figure size.
fig, ax = plt.subplots(figsize=(10,7))

#Choosing the grid style for the visualization.
sns.set_style("darkgrid")

#The code for the visualization. 
sns.barplot(data=top_performing_states, x="state", y= "total_sales_amount", hue = "state", dodge=False)


#Setting the format for the y-axis.
ax.yaxis.set_major_formatter('{x:<8.0f}')

#Setting the title for the legend.
ax.legend(title="States")

#Moving the legend outside the visualization. 
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

#Labelling the axis.
plt.xlabel("States")
plt.ylabel ("Total Amount of Sales")


#Title of the visualization.
plt.title("Top Performing States in Terms of Sales Amount", size = 12)
# Out:
# <AxesSubplot:xlabel='state', ylabel='total_sales_amount'>
# Text(0.5, 0, 'States')
# Text(0, 0.5, 'Total Amount of Sales')
# Text(0.5, 1.0, 'Top Performing States in Terms of Sales Amount')

# %%
#1.5 visualize bottom performing states

#Setting the figure size.
fig, ax = plt.subplots(figsize=(10,7))

#Choosing the grid style for the visualization.
sns.set_style("darkgrid")

#The code for the visualization. 
sns.barplot(data=bottom_performing_states, x="state", y= "total_sales_amount", hue = "state", dodge= False)


#Setting the format for the y-axis.
ax.yaxis.set_major_formatter('{x:<8.0f}')

#Setting the title for the legend.
ax.legend(title="States")

#Moving the legend outside the visualization.
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

#Labelling the axis.
plt.xlabel("States")
plt.ylabel ("Total Amount of Sales")


#Title of the visualization.
plt.title("Low Performing States in Terms of Sales Amount", size = 12)
# Out:
# <AxesSubplot:xlabel='state', ylabel='total_sales_amount'>
# Text(0.5, 0, 'States')
# Text(0, 0.5, 'Total Amount of Sales')
# Text(0.5, 1.0, 'Low Performing States in Terms of Sales Amount')

# %% [markdown]
# ## Part 2: Top performing dealerships
#
# Create a table and visualization of historical cumulative sales amounts by dealership from January 1, 2017 to now.  Only include dealerships located in the *top two* states determined in Part 1.  To do this, perform the following steps:
#
#    1. Write a SELECT query that returns three columns: `dealership_id`,`sales_transaction_date`, and `cumulative_sales`.  `cumulative_sales` represents the cumulative sales amount from January 1, 2017 to the `sales_transaction_date` for dealership identified by `dealership_id`.  There should be a row for each distinct combination of `dealership_id` and `sales_transaction_date` in the `sales` table (*hint*: window function).
#
#
#    2. Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `cumulative_sales_bydealership`.
#
#
#    3. Appropriately visualize historical cumulative sales by dealership across sales transaction dates *in a single plot* (*hint*: seaborn). Visualization should be **presentation ready** (e.g. appropriate and complete titles and legend/axis labels, remove unnecessary/distracting features, display date range for total sales, no overlapping axis labels, integer-valued dealership IDs, states indicated clearly, etc.).

# %%
#2.1 select query
query_2 = """
WITH top_performing_states as (
select s.dealership_id, s.sales_transaction_date, s.sales_amount
from sales s inner join dealerships d on s.dealership_id = d.dealership_id
where (d.state='TX' OR d.state='CA') and s.sales_transaction_date >= '2017-01-01'
)
select dealership_id, sales_transaction_date::DATE, 
sum(sales_amount) over(partition by dealership_id order by sales_transaction_date rows between unbounded preceding and current row)
as cumulative_sales
from top_performing_states
"""

# %%
#2.2 create dataframe
cumulative_sales_bydealership = pd.read_sql_query(query_2,engine)
cumulative_sales_bydealership
#converting data frame data types
convert_dict = {'dealership_id': int,
                'cumulative_sales': float
                }
 
cumulative_sales_bydealership = cumulative_sales_bydealership.astype(convert_dict)
cumulative_sales_bydealership
# Out:
#       dealership_id sales_transaction_date  cumulative_sales
# 0               2.0             2017-01-02           399.992
# 1               2.0             2017-01-06           799.984
# 2               2.0             2017-01-10          1199.976
# 3               2.0             2017-01-10          1799.966
# 4               2.0             2017-01-18          2399.956
# ...             ...                    ...               ...
# 3124           19.0             2019-05-25       5141794.888
# 3125           19.0             2019-05-25       5142144.878
# 3126           19.0             2019-05-28       5142844.868
# 3127           19.0             2019-05-30       5143194.858
# 3128           19.0             2019-05-31       5143509.849
#
# [3129 rows x 3 columns]
#       dealership_id sales_transaction_date  cumulative_sales
# 0                 2             2017-01-02           399.992
# 1                 2             2017-01-06           799.984
# 2                 2             2017-01-10          1199.976
# 3                 2             2017-01-10          1799.966
# 4                 2             2017-01-18          2399.956
# ...             ...                    ...               ...
# 3124             19             2019-05-25       5141794.888
# 3125             19             2019-05-25       5142144.878
# 3126             19             2019-05-28       5142844.868
# 3127             19             2019-05-30       5143194.858
# 3128             19             2019-05-31       5143509.849
#
# [3129 rows x 3 columns]

# %%
#2.3 visualization

#setting the seaborn style to darkgrid
sns.set(style="darkgrid")

#set the plot size
plt.figure(figsize=(10,10))

#creating a seaborn relplot
g=sns.relplot(data=cumulative_sales_bydealership, x="sales_transaction_date", y="cumulative_sales", hue="dealership_id",
              kind="line",size="dealership_id", palette="deep", legend="full", height=7, aspect=1.1)


#adding a title to the seaborn plot
g.fig.suptitle("Historical Cumulative Sales by Dealership in CA & TX")

#setting axis labels to appropirate titles respectively
g.set(ylabel="Cumulative Sales", 
       xlabel="Sales Transaction Date")

#setting legend title
g._legend.set_title('Dealership ID')

#setting additional legend parameters
sns.move_legend(g, "upper left", bbox_to_anchor=(0.85, 0.96), frameon=True)

#setting a rotation parameter for the x axis to avoid overlapping labels
g.set_xticklabels(rotation=35)

#setting style as plain to avoid scientific notation for cumulative sales
plt.ticklabel_format(style='plain', axis='y')

plt.show()

#notes: line plot takes a few minutes to load
# Out:
# Text(0.5, 0.98, 'Historical Cumulative Sales by Dealership in CA & TX')

# %% [markdown]
# ## Part 3: Product mix and sales
#
# Create tables and visualizations to compare the proportion of scooter sales with total sales amount by state for sales from January 2017 to now. To do this, perform the following steps:
#
#    1. Write a SELECT query that returns three columns: `state`,`prop_scooters`, and `total_sales`.  `prop_scooters` represents the proportion of scooter sales out of all sales made from January 2017 to now, `total_sales` represents the total sales amount from January 1, 2017 to now.  There should be one row for each state *and no more*.
#
#
#    2. Use SQLAlchemy to execute the query and store the results in a pandas dataframe called `prop_scoot`.
#
#
#    3. Appropriately visualize the relationship between proportion of scooter sales and total sales *in a single plot*. Visualization should be **presentation ready** (e.g. appropriate and complete titles and legend/axis labels, remove unnecessary/distracting features, display date range for total sales, no overlapping axis labels, etc.).

# %%
#3.1 select query
query_3 = """
    WITH CTE AS(
        SELECT c.state, CAST(SUM(s.sales_amount) AS DECIMAL (20,2)) AS total_sales, 
           SUM(CASE WHEN p.product_type='scooter' THEN 1 
           ELSE 0 END)::FLOAT/COUNT(*)  AS prop_scooter
        FROM sales as s
        INNER JOIN customers as c
        ON s.customer_id= c.customer_id
        INNER JOIN products as p
        ON s.product_id = p.product_id
        WHERE sales_transaction_date::DATE >= '2017-01-01' AND c.state IS NOT NULL
        GROUP BY c.state
        ORDER BY c.state, total_sales
    
        )
        
    SELECT state, total_sales,  prop_scooter
    FROM CTE;
"""

# %%
#3.2 create data frame
prop_scoot = pd.read_sql_query(query_3,engine)
prop_scoot
# Out:
#    state  total_sales  prop_scooter
# 0     AK    670069.33      0.886076
# 1     AL   3197966.52      0.885645
# 2     AR    997384.16      0.854369
# 3     AZ   2266906.98      0.908309
# 4     CA  15857815.99      0.897876
# 5     CO   2694911.29      0.904206
# 6     CT   1931432.95      0.888430
# 7     DC   4747799.88      0.899833
# 8     DE    578364.60      0.823529
# 9     FL  10410607.25      0.897781
# 10    GA   4113195.33      0.892336
# 11    HI    641439.27      0.905882
# 12    IA    753738.45      0.926136
# 13    ID    868799.12      0.893204
# 14    IL   3585130.76      0.904472
# 15    IN   3294076.71      0.886889
# 16    KS   2081442.62      0.889680
# 17    KY   2148697.84      0.872587
# 18    LA   2558471.73      0.907895
# 19    MA   2133992.85      0.882353
# 20    MD   1711213.00      0.901709
# 21    ME     36364.92      0.900000
# 22    MI   3052826.66      0.890306
# 23    MN   3455946.36      0.886311
# 24    MO   4002390.99      0.881607
# 25    MS    835088.79      0.906475
# 26    MT    163149.51      0.962264
# 27    NC   3575996.01      0.879747
# 28    ND    415769.71      0.882353
# 29    NE    833143.33      0.916230
# 30    NH    371714.72      0.852941
# 31    NJ    646548.40      0.948864
# 32    NM    560044.11      0.920000
# 33    NV   1875462.60      0.899281
# 34    NY   9523439.42      0.889960
# 35    OH   4198514.12      0.912593
# 36    OK   2095892.40      0.910596
# 37    OR    961368.60      0.906250
# 38    PA   5031834.85      0.888342
# 39    RI      6099.90      1.000000
# 40    SC   1461923.25      0.905941
# 41    SD     24179.58      1.000000
# 42    TN   3011376.64      0.907692
# 43    TX  15425788.00      0.890336
# 44    UT   1234198.39      0.903226
# 45    VA   4407463.98      0.912917
# 46    VT     30014.96      0.800000
# 47    WA   3072641.42      0.897129
# 48    WI   2063418.28      0.856459
# 49    WV   2133073.28      0.861244
# 50    WY      3249.94      1.000000

# %%
#3.3 visualization

#Setting the figure size.
fig, ax = plt.subplots(figsize = (8,8))

#The code for the visualization. 
sns.scatterplot( data=prop_scoot, x ='prop_scooter', y = 'total_sales', hue='state')

#Setting the title for the legend.
ax.legend(title="States")

#Moving the legend outside the visualization.
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1), ncol=3)


#Setting the format for the y-axis.
ax.yaxis.set_major_formatter('{x:<7.0f}')


#Setting the labels for the axis. 
plt.ylabel("Total Amountof Sales")
plt.xlabel("Proportion of Scooters Sales")

#Setting the title of the visualization.
plt.title("Proportion of Scooters Sales Versus the Total Amount of Sales", size = 11)
# Out:
# <AxesSubplot:xlabel='prop_scooter', ylabel='total_sales'>
# Text(0, 0.5, 'Total Amountof Sales')
# Text(0.5, 0, 'Proportion of Scooters Sales')
# Text(0.5, 1.0, 'Proportion of Scooters Sales Versus the Total Amount of Sales')

# %% [markdown]
# ## Part 4: Takeaways from the analysis
#
# Provide your thoughts about the analysis above by answering the following questions in the blank markdown cells provided below. No code should be run for this section.
#
#
#    1. (Part 1) What are some potential hypotheses as to why the top 5 performing states have the highest sales amounts?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.
#
#
#    2. (Part 1) What are some potential hypotheses as to why the bottom 5 performing states have the lowest sales amounts?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.
#
#
#    3. (Part 2): How would you characterize the historical performance of the dealerships visualized in Part 2 (e.g. good, bad, growing, declining, etc.)?  Describe some of the trends in relative performance over time for the dealerships.  Be specific and cite specific elements of the visualization created in Part 2 to support your claims.  Specify any additional factors you would want to consider that would influence your performance assessment.
#
#
#    4. (Part 3):  How would you describe the relationship between product mix (i.e. proportion of scooters sold) and total sales?  Be specific and cite specific elements of the visualization created in Part 3 to support your claims.
#
#
#    5. (Part 3): What are some potential hypotheses as to why product mix and sales are related in the manner described in 4.4?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.

# %% [markdown]
# ### Part 4 Responses

# %% [markdown]
# For each of the following questions, answer in as much preciseness and clarity that you can. Refer back to the tables and plots that you have created to back up your answers if necessary. Answer each question in the cell below. You are NOT to code anything for this section. This is for you to reflect on the analysis developed in response to Parts 1-3.

# %% [markdown]
# 1. (Part 1) What are some potential hypotheses as to why the top 5 performing states have the highest sales amounts?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.

# %% [markdown]
# Ans 1. The high amount of sales in the top five states can be because of the following reasons:
#         a. Higher income of the customers increasing their purchasing power.
#         b. More aggressive marketing stratgeies.
#         c. Low rate of excise tax i.e. sales tax.
#         d. Higher number of competitors offering
#         e. Lower and competitive prices.
#         f. Large number of customers.
#
#
# Income of the customers, marketing strategies, rate of excise tax, number of competitors, price of the product, and the number of customers can be tested by creating the variables of income of the population, amount of money spent on marketing of the product, the excise-tax-rate since every state in the US have their own set of laws for tax-rate, the number of competitors in the market, price of the product, and the number of customers which can be taken from the tables that we have created in the query by adding the column of number of customers. A linear regression can be used to regress these varaible on the sales amount as the dependent variable and rest of the five variables as independent variable.
#
# Null Hypothesis: There is no statistically significant effect of variables on the sales amount.
#
# Alternative Hypothesis: There is a statistically significant effect of variables on the sales amount.
#
# Using the t-test, and comparing aganist the alpha value of 0.05, if the p-value is less than 0.05 we will reject the null hypothesis and claim that the sales are dependent on the variables of income, money spent on marketing, the rate of excise tax, number of competitors, price charged and the number of customers,  if it is greater than the p-value we will fail to reject the null hypothesis and claim that the sales amount is not dependent on aforementioned five variables. Similary, looking at the 95% confidence interval, if zero does not falls in the interval then we reject the null hypothesis and claim that the variables have a statistically significant relationship with the sales amount, and if zero falls within the 95% confidence interval then we fail to reject the null hypothesis and claim that there is no statistically significant relationship of each variable with the sales amount to analyze the performance of the states.
#
# Another factor that is important from the analysis point of view is that there is a high correlation between the number of the competitors and the price of the product. If there are high number of competitors then they have less liberty to charge higher prices, and would rather give more competitive rates as customers would have more alternatives, increasing the number of sales and hence leading to the high performance of the states.

# %% [markdown]
#  2. (Part 1) What are some potential hypotheses as to why the bottom 5 performing states have the lowest sales amounts?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.

# %% [markdown]
# Ans 2. The low amount of sales in the bottom five states can be because of the following reasons:
#         a. Lower income of customers decreasing their purchasing power.
#         b. Less aggressive marketing stratgeies.
#         c. High amount of excise tax i.e. sales tax.
#         d. Low number of competitors.
#         e. Higher prices.
#         f. Smaller number of customers
#
#
# Income of the customers, marketing strategies, the rate of excise tax, number of competitors, price of the product, and the number of customers can be tested by creating the variables of income of the population, amount of money spent on marketing of the product, the excise-tax-rate since every state tends to hand their own laws which determines the tax rate,the number of competitors in the market, and the number of customers which can be taken from the tables that we have created in the query by adding the column of number of customers. A linear regression can be used to regress these varaible on the sales amount as the dependent variable and rest of the four variables as independent variable.
#
# Null Hypothesis: There is no statistically significant effect of variables on the sales amount.
#
# Alternative Hypothesis: There is a statistically significant effect of variables on the sales amount.
#
# Using the t-test, and comparing aganist the alpha value of 0.05, if the p-value is less than 0.05 we will reject the null hypothesis and claim that the sales are dependent on the variables of income, money spent on marketing, the rate of excise tax, number of competitors, price charged and the number of customers, if it is greater than the p-value we will fail to reject the null hypothesis and claim that the sales amount is not dependent on the five variables. Similary, looking at the 95% confidence interval, if zero does not falls in the interval then we reject the null hypothesis and claim that the variables have a statistically significant relationship with the sales amount, and if zero falls within the 95% confidence interval then we fail to reject the null hypothesis and claim that there is no statistically significant relationship of each variable with the sales amount to analyze the performance of the states.
#
# Another factor that is important from the analysis point of view is that there is a high correlation between the number of the competitors and the price of the product. If there are low number of competitors then they have more liberty to charge higher prices as customers would have less alternatives, decreasing the number of sales and hence leading to the low performance of the states.

# %% [markdown]
# 3. (Part 2): How would you characterize the historical performance of the dealerships visualized in Part 2 (e.g. good, bad, growing, declining, etc.)?  Describe some of the trends in relative performance over time for the dealerships.  Be specific and cite specific elements of the visualization created in Part 2 to support your claims.  Specify any additional factors you would want to consider that could influence your performance assessment.

# %% [markdown]
# Ans 3. The historical performance of the dealerships visualized are growing. These are the top performing dealerships across two top performing states, California and Texas. As seen from the line plot, the dealership that has been performing relatively better than the others over the specified date range is the one with ID=1. The dealership with ID=19 was doing as good as ID=1 till the July of 2018, after that the clear winner is ID=1 with the highest cumulative sales as compared to others from July 2018. Among the 5 dealerships visualized, the one with ID=3 has been performing poorly as compared to others. While all the dealerships have been growing, the dealership with ID=14 has been somewhat constant from October 2018 with very slight increases from April 2019. It can also be seen that on July 2018, all the dealerships except ID=3 had a very similar amount of cumulative sales which may be due to various factors that affect the sales volumes in order for the dealerships to perform almost equally good.
#
# The figure is a seaborn line chart and is titled historic cumulative sales with cumulative sales on the y-axis and the sales transaction date on the x-axis. The date range of the plot is from January 2017 to July 2019. The plot has been grouped with different colors and sized based on the dealership parameter of the dataframe. It is a time series plot which provides us with the historical pattern of cumulative sales for the top performing dealerships over the date range specified.
#
# I would like to consider the state parameter to create two subplots using the column attribute on the state parameter and understand which state has the top performing dealership. Analyzing the dealerships based on the state will provide a clear and consice view of the historal sales trends. Marketing strategies that the dealerships are using also have an effect on the sales of the product. Another important factor is the type of the product which is being sold by the dealerships.

# %% [markdown]
#  4. (Part 3):  How would you describe the relationship between product mix (i.e. proportion of scooters sold) and total sales?  Be specific and cite specific elements of the visualization created in Part 3 to support your claims.

# %% [markdown]
# Ans 4. The plot added is a seaborn scatterplot representing the proportion of scooter sales to the total amount of sales for different states of US. The x axis represents the proportion of scooter sales. The y axis represents the total sales amount of these vehicles. The points in the scatterplot represent the different states in US and their corresponding proportion of scooter sales and the total amount of sales. The colour of points in the scatter plot and their corresponding labelling of states is present in the right side of scatterplot. For example, In Texas, the proportion of sales amount of scooter to total sales amount of vehicle is 0.890336 and the total sales amount of vehicle is 15425788.00. The title of the plot is Proportion of scooter sales versus total sales by state. Since there is no clear upward or downward trend of points, it is evident from the plot that there is no correlation between total amount of sales and proportion of Scooter sales. It is clearly visible from the scatterplot that the proportion of scooter sales for most of the states fall between the range 0.85 to 0.925. So, we can conclude that in most states the proportion of scooter sales lies between 0.85 to 0.925. The state with highest total amount of sales of vehicles is California (15857815.99) having the proportion of scooter sales as 0.897876.  The state with the least total amount of sales of vehicle is Wyoming (3249.94) having the proportion of scooter sales as 1. Other inference from the scatterplot is the states with highest (1) and lowest (0.8) proportion of scooter sales have low total amount of sales of vehicle.

# %% [markdown]
#  5. (Part 3): What are some potential hypotheses as to why product mix and sales are related in the manner described in 5?  Describe how you would test your hypotheses in further analysis.  Do not conduct any additional analyses or write any more queries, just describe in words.

# %% [markdown]
# Ans 5. The proportion of scooter sales to the total amount of sales for different states of US is greater than 80% for the given states which indicates that the scooter sales are comparatively higher. One of the hypotheses is that customers find it convenient to use scooters in traffic when compared to other vehicles which results in higher scooter sales. The second hypothesis is that customers find scooters are more fuel efficient when compared to other vehicles which potentially resulted in higher sales rate of scooter. Third hypothesis is that customers find scooters safer when compared to other vehicles.
# To test these 3 different hypotheses, one of the potential techniques is to use paired t test. For the first hypothesis it will test the effect of convenience on the sales of scooters and other vehicles of a state. For the second hypothesis it will test the effect of fuel efficiency on the sales of scooters and other vehicles of a state. For the third hypothesis it will test the effect of safety on the sales of scooters and other vehicles of a state.
